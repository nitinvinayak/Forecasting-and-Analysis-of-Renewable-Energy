# %%
#Libraries Used
import pandas as pd
import numpy as np

# %%
#Constants
filename="data/year_2000.csv"

# %%
#Load dataset
data=pd.read_csv(filename, header=None)

# %%
data.head()
# Out:
#        0            1     2      3        4         5          6          7   \
# 0  Source  Location ID  City  State  Country  Latitude  Longitude  Time Zone
# 1    SUNY        13719     -      -    India     23.95      71.15        5.5
# 2    Year        Month   Day   Hour   Minute       DHI        DNI        GHI
# 3    2000            1     1      0       30         0          0          0
# 4    2000            1     1      1       30         0          0          0
#
#              8                9   ...                    25          26  \
# 0     Elevation  Local Time Zone  ...  Wind Direction Units  Wind Speed
# 1             0              5.5  ...               Degrees         m/s
# 2  Clearsky DHI     Clearsky DNI  ...                   NaN         NaN
# 3             0                0  ...                   NaN         NaN
# 4             0                0  ...                   NaN         NaN
#
#                  27           28             29              30  \
# ...
